# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install pandas numpy seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (2.3.4)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp311-cp311-win_amd64.whl.metadata (80 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from pandas) (2025.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=9 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from matplotlib) (12.0.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.11.0-cp311-cp311-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.3 MB 2.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.3 MB 2.9 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.3 MB 2.1 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.3 MB 3.0 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.3 MB 3.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.3 MB 3.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.5/9.3 MB 3.5 MB/s eta 0:00:02
#    --------------------------- ------------ 6.3/9.3 MB 3.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.3 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.3 MB/s  0:00:02
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp311-cp311-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 4.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.4 MB 3.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.4 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 3.6 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------------- ---------------------- 3/7 [cycler]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------------- 7/7 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pyparsing-3.3.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo
hcv_data = fetch_ucirepo(id=571)

# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Using cached ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from ucimlrepo) (2.3.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from ucimlrepo) (2025.10.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\envs\forest-qa\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Using cached ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.DataFrame(data=hcv_data.data.features,columns=hcv_data.data.features_names)

# %%
target_df=pd.DataFrame(data=hcv_data.data.targets,columns=hcv_data.data.targets_names)

# %%
df=pd.concat([df,target_df],axis=1)

# %%
df.sample(5)
# Out:
#      Age Sex   ALB    ALP   AST   BIL    CHE  CHOL  CREA   CGT  PROT   ALT  \
# 611   64   f  24.0  102.8  44.4  20.0   1.54  3.02  63.0  35.9  71.3   2.9
# 529   64   f  43.0   52.7  29.2   5.5  11.69  6.00  63.0  61.9  73.4  31.6
# 186   49   m  39.1   62.1  19.6   3.5   9.19  4.82  85.0  19.4  69.8  23.8
# 147   46   m  42.6   61.6  21.4  10.2   7.00  6.13  89.0  19.9  73.7  18.6
# 493   56   f  34.7   90.3  21.6   3.5   8.07  5.45  67.0   9.0  69.4  22.7
#
#           Category
# 611    3=Cirrhosis
# 529  0=Blood Donor
# 186  0=Blood Donor
# 147  0=Blood Donor
# 493  0=Blood Donor

# %%
hcv_data.metadata
# Out:
# {'uci_id': 571,
#  'name': 'HCV data',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/571/hcv+data',
#  'data_url': 'https://archive.ics.uci.edu/static/public/571/data.csv',
#  'abstract': 'The data set contains laboratory values of blood donors and Hepatitis C patients and demographic values like age.',
#  'area': 'Health and Medicine',
#  'tasks': ['Classification', 'Clustering'],
#  'characteristics': ['Multivariate'],
#  'num_instances': 615,
#  'num_features': 12,
#  'feature_types': ['Integer', 'Real'],
#  'demographics': ['Age', 'Sex'],
#  'target_col': ['Category'],
#  'index_col': ['ID'],
#  'has_missing_values': 'yes',
#  'missing_values_symbol': 'NaN',
#  'year_of_dataset_creation': 2020,
#  'last_updated': 'Fri Nov 03 2023',
#  'dataset_doi': '10.24432/C5D612',
#  'creators': ['Ralf Lichtinghagen', 'Frank Klawonn', 'Georg Hoffmann'],
#  'intro_paper': {'ID': 237,
#   'type': 'NATIVE',
#   'title': 'Using machine learning techniques to generate laboratory diagnostic pathways—a case study',
#   'authors': 'Georg F. Hoffmann, A. Bietenbeck, R. Lichtinghagen, F. Klawonn',
#   'venue': 'Journal of Laboratory and Precision Medicine',
#   'year': 2018,
#   'journal': None,
#   'DOI': '10.21037/jlpm.2018.06.01',
#   'URL': 'https://www.semanticscholar.org/paper/26d42f15a80f3629f5de44262891dd25979e4be3',
#   'sha': None,
#   'corpus': None,
#   'arxiv': None,
#   'mag': None,
#   'acl': None,
#   'pmid': None,
#   'pmcid': None},
#  'additional_info': {'summary': "The target attribute for classification is Category (blood donors vs. Hepatitis C, including its progress: 'just' Hepatitis C, Fibrosis, Cirrhosis).",
#   'purpose': None,
#   'funded_by': None,
#   'instances_represent': 'Instances are patients',
#   'recommended_data_splits': None,
#   'sensitive_data': None,
#   'preprocessing_description': None,
#   'variable_info': "All attributes except Category and Sex are numerical. The laboratory data are the attributes 5-14. \r\n\t 1) X (Patient ID/No.)\r\n\t 2) Category (diagnosis) (values: '0=Blood Donor', '0s=suspect Blood Donor', '1=Hepatitis', '2=Fibrosis', '3=Cirrhosis')\r\n\t 3) Age (in years)\r\n\t 4) Sex (f,m)\r\n\t 5) ALB\r\n\t 6) ALP\r\n\t 7) ALT\r\n\t 8) AST\r\n\t 9) BIL\r\n\t10) CHE\r\n\t11) CHOL\r\n\t12) CREA\r\n\t13) GGT\r\n\t14) PROT\r\n",
#   'citation': None}}

# %%
metadata={'uci_id': 571,
 'name': 'HCV data',
 'repository_url': 'https://archive.ics.uci.edu/dataset/571/hcv+data',
 'data_url': 'https://archive.ics.uci.edu/static/public/571/data.csv',
 'abstract': 'The data set contains laboratory values of blood donors and Hepatitis C patients and demographic values like age.',
 'area': 'Health and Medicine',
 'tasks': ['Classification', 'Clustering'],
 'characteristics': ['Multivariate'],
 'num_instances': 615,
 'num_features': 12,
 'feature_types': ['Integer', 'Real'],
 'demographics': ['Age', 'Sex'],
 'target_col': ['Category'],
 'index_col': ['ID'],
 'has_missing_values': 'yes',
 'missing_values_symbol': 'NaN',
 'year_of_dataset_creation': 2020,
 'last_updated': 'Fri Nov 03 2023',
 'dataset_doi': '10.24432/C5D612',
 'creators': ['Ralf Lichtinghagen', 'Frank Klawonn', 'Georg Hoffmann'],
 'intro_paper': {'ID': 237,
  'type': 'NATIVE',
  'title': 'Using machine learning techniques to generate laboratory diagnostic pathways—a case study',
  'authors': 'Georg F. Hoffmann, A. Bietenbeck, R. Lichtinghagen, F. Klawonn',
  'venue': 'Journal of Laboratory and Precision Medicine',

  'recommended_data_splits': None,
  'sensitive_data': None,
  'preprocessing_description': None,
  'variable_info': "All attributes except Category and Sex are numerical. The laboratory data are the attributes 5-14. \r\n\t 1) X (Patient ID/No.)\r\n\t 2) Category (diagnosis) (values: '0=Blood Donor', '0s=suspect Blood Donor', '1=Hepatitis', '2=Fibrosis', '3=Cirrhosis')\r\n\t 3) Age (in years)\r\n\t 4) Sex (f,m)\r\n\t 5) ALB\r\n\t 6) ALP\r\n\t 7) ALT\r\n\t 8) AST\r\n\t 9) BIL\r\n\t10) CHE\r\n\t11) CHOL\r\n\t12) CREA\r\n\t13) GGT\r\n\t14) PROT\r\n",
  'citation': None}}


flatted_metadata=pd.json_normalize(metadata)
df_metadata=pd.DataFrame(data=flatted_metadata)
pd.set_option('display.max_columns', None)
print(df_metadata.to_string(index=False))
df_metadata.to_csv('hcv_data_metadata.txt',sep='\t', index=False)
# Out:
#  uci_id     name                                   repository_url                                               data_url                                                                                                          abstract                area                        tasks characteristics  num_instances  num_features   feature_types demographics target_col index_col has_missing_values missing_values_symbol  year_of_dataset_creation    last_updated     dataset_doi                                            creators  intro_paper.ID intro_paper.type                                                                         intro_paper.title                                            intro_paper.authors                            intro_paper.venue intro_paper.recommended_data_splits intro_paper.sensitive_data intro_paper.preprocessing_description                                                                                                                                                                                                                                                                                                                                                                                                                         intro_paper.variable_info intro_paper.citation
#     571 HCV data https://archive.ics.uci.edu/dataset/571/hcv+data https://archive.ics.uci.edu/static/public/571/data.csv The data set contains laboratory values of blood donors and Hepatitis C patients and demographic values like age. Health and Medicine [Classification, Clustering]  [Multivariate]            615            12 [Integer, Real]   [Age, Sex] [Category]      [ID]                yes                   NaN                      2020 Fri Nov 03 2023 10.24432/C5D612 [Ralf Lichtinghagen, Frank Klawonn, Georg Hoffmann]             237           NATIVE Using machine learning techniques to generate laboratory diagnostic pathways—a case study Georg F. Hoffmann, A. Bietenbeck, R. Lichtinghagen, F. Klawonn Journal of Laboratory and Precision Medicine                                None                       None                                  None All attributes except Category and Sex are numerical. The laboratory data are the attributes 5-14. \r\n\t 1) X (Patient ID/No.)\r\n\t 2) Category (diagnosis) (values: '0=Blood Donor', '0s=suspect Blood Donor', '1=Hepatitis', '2=Fibrosis', '3=Cirrhosis')\r\n\t 3) Age (in years)\r\n\t 4) Sex (f,m)\r\n\t 5) ALB\r\n\t 6) ALP\r\n\t 7) ALT\r\n\t 8) AST\r\n\t 9) BIL\r\n\t10) CHE\r\n\t11) CHOL\r\n\t12) CREA\r\n\t13) GGT\r\n\t14) PROT\r\n                 None

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ALB', 'ALP', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA', 'CGT',
#        'PROT', 'ALT', 'Category'],
#       dtype='object')

# %%
df.shape
print("no of rows:"+str(df.shape[0]))
print("no of columns:"+str(df.shape[1]))
# Out:
# no of rows:615
# no of columns:13

# %%
df.info
# Out:
# <bound method DataFrame.info of      Age Sex   ALB    ALP    AST   BIL    CHE  CHOL   CREA    CGT  PROT  \
# 0     32   m  38.5   52.5   22.1   7.5   6.93  3.23  106.0   12.1  69.0
# 1     32   m  38.5   70.3   24.7   3.9  11.17  4.80   74.0   15.6  76.5
# 2     32   m  46.9   74.7   52.6   6.1   8.84  5.20   86.0   33.2  79.3
# 3     32   m  43.2   52.0   22.6  18.9   7.33  4.74   80.0   33.8  75.7
# 4     32   m  39.2   74.1   24.8   9.6   9.15  4.32   76.0   29.9  68.7
# ..   ...  ..   ...    ...    ...   ...    ...   ...    ...    ...   ...
# 610   62   f  32.0  416.6  110.3  50.0   5.57  6.30   55.7  650.9  68.5
# 611   64   f  24.0  102.8   44.4  20.0   1.54  3.02   63.0   35.9  71.3
# 612   64   f  29.0   87.3   99.0  48.0   1.66  3.63   66.7   64.2  82.0
# 613   46   f  33.0    NaN   62.0  20.0   3.56  4.20   52.0   50.0  71.0
# 614   59   f  36.0    NaN   80.0  12.0   9.07  5.30   67.0   34.0  68.0
#
#        ALT       Category
# 0      7.7  0=Blood Donor
# 1     18.0  0=Blood Donor
# 2     36.2  0=Blood Donor
# 3     30.6  0=Blood Donor
# 4     32.6  0=Blood Donor
# ..     ...            ...
# 610    5.9    3=Cirrhosis
# 611    2.9    3=Cirrhosis
# 612    3.5    3=Cirrhosis
# 613   39.0    3=Cirrhosis
# 614  100.0    3=Cirrhosis
#
# [615 rows x 13 columns]>

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ALB          1
# ALP         18
# AST          0
# BIL          0
# CHE          0
# CHOL        10
# CREA         0
# CGT          0
# PROT         1
# ALT          1
# Category     0
# dtype: int64

# %%
df.describe()
# Out:
#               Age         ALB         ALP         AST         BIL         CHE  \
# count  615.000000  614.000000  597.000000  615.000000  615.000000  615.000000
# mean    47.408130   41.620195   68.283920   34.786341   11.396748    8.196634
# std     10.055105    5.780629   26.028315   33.090690   19.673150    2.205657
# min     19.000000   14.900000   11.300000   10.600000    0.800000    1.420000
# 25%     39.000000   38.800000   52.500000   21.600000    5.300000    6.935000
# 50%     47.000000   41.950000   66.200000   25.900000    7.300000    8.260000
# 75%     54.000000   45.200000   80.100000   32.900000   11.200000    9.590000
# max     77.000000   82.200000  416.600000  324.000000  254.000000   16.410000
#
#              CHOL         CREA         CGT        PROT         ALT
# count  605.000000   615.000000  615.000000  614.000000  614.000000
# mean     5.368099    81.287805   39.533171   72.044137   28.450814
# std      1.132728    49.756166   54.661071    5.402636   25.469689
# min      1.430000     8.000000    4.500000   44.800000    0.900000
# 25%      4.610000    67.000000   15.700000   69.300000   16.400000
# 50%      5.300000    77.000000   23.300000   72.200000   23.000000
# 75%      6.060000    88.000000   40.200000   75.400000   33.075000
# max      9.670000  1079.100000  650.900000   90.000000  325.300000

# %%
df.isnull().sum().sum()
# Out:
# np.int64(31)

# %%
figg, axx = plt.subplots(3, 5, figsize=(20, 10))

axx = axx.flatten()

for i, column in enumerate(df.columns):
    df[column].hist(ax=axx[i], bins=10, color='red', alpha=0.7)
    axx[i].set_title(column)
    axx[i].set_xlabel('Value')
    axx[i].set_ylabel('Frequency')

for j in range(i + 1, len(axx)):
    axx[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
def draw_univariate_plot(dataset, rows, cols, plot_type):
    column_names=dataset.columns.values
    number_of_column=len(column_names)
    fig, axarr=plt.subplots(rows,cols, figsize=(20,10))

    counter=0
    
    for i in range(rows):
        for j in range(cols):

            if counter >= number_of_column:
                axarr[i][j].set_visible(False) 
                continue

            if column_names[counter]=='target':
                break

            if 'violin' in plot_type:
                sns.violinplot(x='target', y=column_names[counter],data=dataset, ax=axarr[i][j])
            elif 'box'in plot_type : # You can add other plot types here
                sns.boxplot(x=None,y=column_names[counter],data=dataset,ax=axarr[i][j],width=0.5)

            axarr[i][j].set_title(column_names[counter])
            counter += 1
            
            if counter==(number_of_column-1,):
                break

# %%
z = df.drop(['Sex', 'Category'], axis=1)
draw_univariate_plot(dataset=z, rows=3, cols=5, plot_type="box")
plt.subplots_adjust(hspace=0.2, wspace=0.4) 
plt.show()

# %%
numeric_df = df.select_dtypes(include=['number'])

for col in numeric_df.columns:
    Q1 = numeric_df[col].quantile(0.25)
    Q3 = numeric_df[col].quantile(0.75)
    
    # Calculate the Interquartile Range (IQR)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    numeric_df = numeric_df[(numeric_df[col] >= lower_bound) & (numeric_df[col] <= upper_bound)]

df_cleaned = pd.concat([numeric_df, df.select_dtypes(exclude=['number'])], axis=1)
df_cleaned.drop(['Sex', 'Category'], axis=1, inplace=True)
print(numeric_df.columns)
print(numeric_df.shape)
# Out:
# Index(['Age', 'ALB', 'ALP', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA', 'CGT', 'PROT',
#        'ALT'],
#       dtype='object')
# (386, 11)

# %%
draw_univariate_plot(dataset=df_cleaned, rows=3, cols=5, plot_type="box")
plt.subplots_adjust(hspace=0.2, wspace=0.4) 
plt.show()

# %%
df.isna().sum()
# Out:
# Age          0
# Sex          0
# ALB          1
# ALP         18
# AST          0
# BIL          0
# CHE          0
# CHOL        10
# CREA         0
# CGT          0
# PROT         1
# ALT          1
# Category     0
# dtype: int64

# %%
df.select_dtypes(include=['int64', 'float64']).skew()
# Out:
# Age      0.267134
# ALB     -0.176768
# ALP      4.654921
# AST      4.940327
# BIL      8.385437
# CHE     -0.110233
# CHOL     0.375828
# CREA    15.169291
# CGT      5.632734
# PROT    -0.963687
# ALT      5.506114
# dtype: float64

# %%
df['ALB'] = df.ALB.fillna(df.ALB.mean())
df['ALP'] = df.ALP.fillna(df.ALP.median())
df['ALT'] = df.ALT.fillna(df.ALT.median())
df['CHOL'] = df.CHOL.fillna(df.CHOL.mean())
df['PROT'] = df.PROT.fillna(df.PROT.median())

# %%
X = df.drop('Category', axis=1)
Y = pd.DataFrame(df['Category'], index=X.index, columns=['Category'])

print(X, Y)
# Out:
#      Age Sex   ALB    ALP    AST   BIL    CHE  CHOL   CREA    CGT  PROT    ALT
# 0     32   m  38.5   52.5   22.1   7.5   6.93  3.23  106.0   12.1  69.0    7.7
# 1     32   m  38.5   70.3   24.7   3.9  11.17  4.80   74.0   15.6  76.5   18.0
# 2     32   m  46.9   74.7   52.6   6.1   8.84  5.20   86.0   33.2  79.3   36.2
# 3     32   m  43.2   52.0   22.6  18.9   7.33  4.74   80.0   33.8  75.7   30.6
# 4     32   m  39.2   74.1   24.8   9.6   9.15  4.32   76.0   29.9  68.7   32.6
# ..   ...  ..   ...    ...    ...   ...    ...   ...    ...    ...   ...    ...
# 610   62   f  32.0  416.6  110.3  50.0   5.57  6.30   55.7  650.9  68.5    5.9
# 611   64   f  24.0  102.8   44.4  20.0   1.54  3.02   63.0   35.9  71.3    2.9
# 612   64   f  29.0   87.3   99.0  48.0   1.66  3.63   66.7   64.2  82.0    3.5
# 613   46   f  33.0   66.2   62.0  20.0   3.56  4.20   52.0   50.0  71.0   39.0
# 614   59   f  36.0   66.2   80.0  12.0   9.07  5.30   67.0   34.0  68.0  100.0
#
# [615 rows x 12 columns]           Category
# 0    0=Blood Donor
# 1    0=Blood Donor
# 2    0=Blood Donor
# 3    0=Blood Donor
# 4    0=Blood Donor
# ..             ...
# 610    3=Cirrhosis
# 611    3=Cirrhosis
# 612    3=Cirrhosis
# 613    3=Cirrhosis
# 614    3=Cirrhosis
#
# [615 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
gender_transform = le.fit_transform(X['Sex']).astype(int)
X['Sex'] = gender_transform

gender_classes = le.classes_
print(le.classes_) # F=0, M=1
print(X['Sex'].sample(5))

label_mapping = {label: index for index, label in zip(le.transform(gender_classes), gender_classes)}
print("Label Mapping Dictionary:", label_mapping)
# Out:
# ['f' 'm']
# 522    0
# 245    1
# 449    0
# 82     1
# 371    0
# Name: Sex, dtype: int64
# Label Mapping Dictionary: {'f': np.int64(0), 'm': np.int64(1)}

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
class_transform = le.fit_transform(Y['Category']).astype(int)
Y['Category'] = class_transform
print(le.classes_)
print(Y['Category'].sample(5))

label_mapping = {label: index for index, label in zip(le.transform(le.classes_), le.classes_)}

print("Label Mapping Dictionary:", label_mapping)
# Out:
# ['0=Blood Donor' '0s=suspect Blood Donor' '1=Hepatitis' '2=Fibrosis'
#  '3=Cirrhosis']
# 377    0
# 508    0
# 555    2
# 90     0
# 240    0
# Name: Category, dtype: int64
# Label Mapping Dictionary: {'0=Blood Donor': np.int64(0), '0s=suspect Blood Donor': np.int64(1), '1=Hepatitis': np.int64(2), '2=Fibrosis': np.int64(3), '3=Cirrhosis': np.int64(4)}

# %%
df = pd.concat([X, Y], axis=1)
df.head()
# Out:
#    Age  Sex   ALB   ALP   AST   BIL    CHE  CHOL   CREA   CGT  PROT   ALT  \
# 0   32    1  38.5  52.5  22.1   7.5   6.93  3.23  106.0  12.1  69.0   7.7
# 1   32    1  38.5  70.3  24.7   3.9  11.17  4.80   74.0  15.6  76.5  18.0
# 2   32    1  46.9  74.7  52.6   6.1   8.84  5.20   86.0  33.2  79.3  36.2
# 3   32    1  43.2  52.0  22.6  18.9   7.33  4.74   80.0  33.8  75.7  30.6
# 4   32    1  39.2  74.1  24.8   9.6   9.15  4.32   76.0  29.9  68.7  32.6
#
#    Category
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# print(type(X_train), type(X_test), type(Y_train), type(Y_test))

standard_scaler = StandardScaler()
X_train_scaled = standard_scaler.fit_transform(X_train)
X_test_scaled = standard_scaler.transform(X_test)

# %%
print(type(X))
print(type(X_train))
print(type(X_test))
print(type(X_train_scaled))
print(type(X_test_scaled))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(type(Y))
print(type(Y_train))
print(type(Y_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
Y_train = Y_train.values
Y_test = Y_test.values
print(type(Y_train))
print(type(Y_test))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import numpy as np

# %%
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
Y_train_tensor = torch.tensor(Y_train.ravel(), dtype=torch.long)
Y_test_tensor = torch.tensor(Y_test.ravel(), dtype=torch.long)

train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, Y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f'train batches : {len(train_loader)}|test batches : {len(test_loader)}')
print(f'input features : {X_train_tensor.shape[1]} | output classes : {len(np.unique(Y_train))}')
# Out:
# train batches : 16|test batches : 4
# input features : 12 | output classes : 5

# %%
# ─── 3. Define the Neural Network ─────────────────────────────────────────────
# Architecture: 12 → 64 → 32 → 16 → 5 (5 HCV categories)
# BatchNorm stabilizes training, Dropout prevents overfitting

class HCVNet(nn.Module):
    def __init__(self, input_size, num_classes):
        super(HCVNet, self).__init__()

        self.fc1 = nn.Linear(input_size, 64)
        self.bn1 = nn.BatchNorm1d(64)           # normalizes activations
        self.dropout1 = nn.Dropout(0.3)         # randomly zeros 30% of neurons

        self.fc2 = nn.Linear(64, 32)
        self.bn2 = nn.BatchNorm1d(32)
        self.dropout2 = nn.Dropout(0.3)

        self.fc3 = nn.Linear(32, 16)

        self.output = nn.Linear(16, num_classes) # raw logits — no activation here!

    def forward(self, x):
        x = F.relu(self.bn1(self.fc1(x)))
        x = self.dropout1(x)

        x = F.relu(self.bn2(self.fc2(x)))
        x = self.dropout2(x)

        x = F.relu(self.fc3(x))

        x = self.output(x)   # CrossEntropyLoss applies softmax internally
        return x


# ─── 4. Instantiate model, loss, optimizer ────────────────────────────────────
device    = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model     = HCVNet(input_size=X_train_scaled.shape[1], num_classes=5).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

print(model)
print(f'\nDevice: {device}')
# Out:
# HCVNet(
#   (fc1): Linear(in_features=12, out_features=64, bias=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=32, out_features=16, bias=True)
#   (output): Linear(in_features=16, out_features=5, bias=True)
# )
#
# Device: cpu

# %%
# ─── 5. Training Loop ─────────────────────────────────────────────────────────
epochs     = 50
train_losses = []
train_accs   = []

for epoch in range(epochs):
    model.train()              # activate dropout + batchnorm in train mode
    running_loss = 0.0
    correct = 0
    total   = 0

    for X_batch, Y_batch in train_loader:
        X_batch, Y_batch = X_batch.to(device), Y_batch.to(device)

        optimizer.zero_grad()          # clear gradients from last step
        outputs = model(X_batch)       # forward pass
        loss    = criterion(outputs, Y_batch)  # compute loss
        loss.backward()                # backpropagation
        optimizer.step()               # update weights

        running_loss += loss.item()
        _, predicted  = torch.max(outputs, 1)
        correct += (predicted == Y_batch).sum().item()
        total   += Y_batch.size(0)

    epoch_loss = running_loss / len(train_loader)
    epoch_acc  = 100 * correct / total
    train_losses.append(epoch_loss)
    train_accs.append(epoch_acc)

    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}]  Loss: {epoch_loss:.4f}  Accuracy: {epoch_acc:.2f}%')
# Out:
# Epoch [10/50]  Loss: 0.3052  Accuracy: 89.43%
# Epoch [20/50]  Loss: 0.2103  Accuracy: 92.07%
# Epoch [30/50]  Loss: 0.1928  Accuracy: 92.48%
# Epoch [40/50]  Loss: 0.1496  Accuracy: 94.92%
# Epoch [50/50]  Loss: 0.1538  Accuracy: 94.72%

# %%
# ─── 6. Plot Training Loss & Accuracy ─────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(train_losses, color='steelblue')
axes[0].set_title('Training Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')

axes[1].plot(train_accs, color='green')
axes[1].set_title('Training Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy (%)')

plt.tight_layout()
plt.show()

# %%
# ─── 7. Evaluation on Test Set ────────────────────────────────────────────────
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model.eval()                   # deactivates dropout + batchnorm
all_preds  = []
all_labels = []

with torch.no_grad():          # no gradient computation during eval
    for X_batch, Y_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(Y_batch.numpy())

print('=== Neural Network — Test Results ===')
print(classification_report(all_labels, all_preds))

# Confusion Matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix — Neural Network')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# === Neural Network — Test Results ===
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        96
#            1       1.00      0.33      0.50         3
#            2       0.75      0.33      0.46         9
#            3       0.25      0.17      0.20         6
#            4       1.00      0.56      0.71         9
#
#     accuracy                           0.86       123
#    macro avg       0.78      0.48      0.56       123
# weighted avg       0.85      0.86      0.84       123
